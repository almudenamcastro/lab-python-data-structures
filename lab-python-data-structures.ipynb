# %% [markdown]
# # Lab | Data Structures

# %% [markdown]
# ## Exercise: Managing Customer Orders
#
# As part of a business venture, you are starting an online store that sells various products. To ensure smooth operations, you need to develop a program that manages customer orders and inventory. Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.
#
# Follow the steps below to complete the exercise:

# %% [markdown]
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".

# %%
products = ["t-shirt", "mug", "hat", "book", "keychain"]

# %% [markdown]
# 2. Create an empty dictionary called `inventory`.

# %%
inventory = {}

# %% [markdown]
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.

# %%
for product in products: 
    while product not in inventory: 
        try:
            inventory[product] = int(input(f"How many {product}s do you have? "))
        except:
            print("sorry, I need an integer, your answer wasn't registered")

inventory
# Out:
# {'t-shirt': 0, 'mug': 13, 'hat': 42, 'book': 25, 'keychain': 5}

# %% [markdown]
# 4. Create an empty set called `customer_orders`

# %%
customer_orders=set()

# %% [markdown]
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.

# %%
while len(customer_orders) < 3:
  product = input('''What product to you want to add to your order?
            ''' + str(list(inventory.keys())))
  if product in inventory:
    if inventory[product] > 0:     
      customer_orders.add(product)
      print(f"1 {product} was added to your order")
    else: 
      print(f'''sorry, we have run out of {product}. Try a different product:
      '''  + str(list(inventory.keys())))
  else: 
    print(f'''sorry, we don't have {product}. Choose between the following options:
    '''  + str(list(inventory.keys())))

print("this is your order: ", customer_orders)
# Out:
# sorry, we have run out of t-shirt. Try a different product:
#       ['t-shirt', 'mug', 'hat', 'book', 'keychain']
# 1 mug was added to your order
# 1 mug was added to your order
# 1 book was added to your order
# 1 hat was added to your order
# this is your order:  {'book', 'mug', 'hat'}

# %% [markdown]
# 6. Print the products in the `customer_orders` set.

# %%
print("this is the customer order:", customer_orders)
# Out:
# this is the customer order: {'t-shirt', 'book', 'mug'}

# %% [markdown]
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.

# %%
print(f"The order contains {len(customer_orders)} products")

for product in customer_orders:
  print(f"The customer ordered {100*1/inventory[product]:.2f} % of the {product}s in your inventory")


order_status=(len(customer_orders) , 100*len(customer_orders)/sum(inventory.values()))

print(f"Globally, the customer ordered {order_status[1]:.2f} % of your total inventory")
# Out:
# The order contains 3 products
# The customer ordered 33.33 % of the t-shirts in your inventory
# The customer ordered 2.86 % of the books in your inventory
# The customer ordered 6.67 % of the mugs in your inventory
# Globally, the customer ordered 2.97 % or your total products

# %% [markdown]
# 8. Print the order statistics using the following format:
#    ```
#    Order Statistics:
#    Total Products Ordered: <total_products_ordered>
#    Percentage of Products Ordered: <percentage_ordered>%
#    ```

# %%
print(f'''Order Statistics:
Total Products Ordered: {order_status[0]}
Percentage of Products Ordered: {order_status[1]:.2f} %
''')
# Out:
# Order Statistics:
# Total Products Ordered: 3
# Percentage of Products Ordered: 2.97 %

# %% [markdown]
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.

# %%
for product in customer_orders:
    inventory[product]-=1

sum(inventory.values())
# Out:
# 95

# %%
inventory
# Out:
# {'t-shirt': 1, 'mug': 13, 'hat': 16, 'book': 33, 'keychain': 32}

# %% [markdown]
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.

# %%
print("this is your updated inventory: ")
for key in inventory:
    print(inventory[key], key+"s")
# Out:
# this is your updated inventory:
# 0 t-shirts
# 13 mugs
# 42 hats
# 25 books
# 5 keychains

# %% [markdown]
# Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.
